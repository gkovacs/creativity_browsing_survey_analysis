# %%
from analysis_base import *

# %%
print_yaml(get_survey_results_for_user('geza'))
# Out:
# __v: 0
# _id: {$oid: 572a87218b8b180300b15dc9}
# answer_array:
# - {correct_answer: cheese, difficulty: Very Easy, guessed_answer: cheese}
# - {correct_answer: boat, difficulty: Very Easy, guessed_answer: boat}
# - {correct_answer: chair, difficulty: Very Easy, guessed_answer: chair}
# - {correct_answer: forest, difficulty: Very Easy, guessed_answer: natural}
# - {correct_answer: fire, difficulty: Very Easy, guessed_answer: ''}
# - {correct_answer: day, difficulty: Easy, guessed_answer: ''}
# - {correct_answer: tape, difficulty: Very Easy, guessed_answer: ''}
# - {correct_answer: book, difficulty: Very Easy, guessed_answer: hole}
# - {correct_answer: bank, difficulty: Easy, guessed_answer: bank}
# - {correct_answer: blind, difficulty: Very Easy, guessed_answer: ''}
# - {correct_answer: coat, difficulty: Easy, guessed_answer: racoon}
# - {correct_answer: hole, difficulty: Medium, guessed_answer: sly}
# - {correct_answer: candle, difficulty: Medium, guessed_answer: ''}
# ...

# %%
print_counter(get_hours_spent_on_domain_category_for_user('geza'))
# Out:
#  82.8623976841
# General Reference & Learning 58.1136220933
# Uncategorized 52.9918518281
# General Software Development 48.7632624297
# Email 45.3637621568
# General Social Networking 43.7992214296
# Search 41.1264720577
# Quality Assurance 26.8480075197
# Writing 17.2726851149
# Calendars 15.8845652528
# Engineering & Technology 11.1323255616
# General News & Opinion 11.0653787301
# Instant Message 10.0692997723
# Video 9.73896616842
# General Shopping 5.70903105815
# Science & Technology 5.46300968519
# General Business 3.67837522875
# General Entertainment 2.4352692924
# Intelligence 2.23078178236
# Photos 2.05464656989
# General Communication & Scheduling 1.28186581421
# General Utilities 0.955422784356
# Marketing 0.948606240845
# File Sharing 0.941689261949
# Comedy 0.903907430081
# Internet Utilities 0.903753514676
# Data Modeling & Analysis 0.767033093533
# Games 0.690453755086
# Editing & IDEs 0.578934620294
# Travel & Outdoors 0.487001789619
# Presentation 0.484614843886
# ...

# %%
print_counter(get_hours_spent_on_domain_productivity_for_user('geza'))
# Out:
# 0 239.528661345
# 2 102.180699791
# -2 79.0244205117
# 1 71.1604725245
# -1 15.6936995966

# %%
print_yaml(list_users())
# Out:
# [shivaal, guest86857486405, jess, geza, guest00165780227]

# %%
print get_hours_spent_online_for_user('jess')
# Out:
# 335.473802318

# %%
print get_hours_spent_online_for_user('geza')
# Out:
# 507.587953768

# %%
print get_hours_spent_online_for_user('shivaal')
# Out:
# 453.828596779

# %%
print_counter(get_hours_spent_on_domains_for_user('shivaal'))
# Out:
# docs.google.com 50.9505152577
# www.facebook.com 47.9491478893
# www.messenger.com 30.8438371754
# www.google.com 29.8193892806
# web.stanford.edu 22.1932980266
# mail.google.com 21.3583190571
# www.youtube.com 21.2033731272
# localhost:3000 15.54857595
# piazza.com 13.1625369489
# m.facebook.com 10.2351024687
#  9.20668123617
# stackoverflow.com 7.93413714125
# drive.google.com 6.18965462653
# i.imgur.com 5.92555030558
# canvas.stanford.edu 5.08415334317
# github.com 4.96418808038
# keep.google.com 3.74796362183
# www.reddit.com 3.74596126438
# imgur.com 3.68404104241
# www.amazon.com 3.53625874478
# localhost:8000 3.09521014459
# en.wikipedia.org 3.09078093391
# www.glassdoor.com 2.63060545932
# mvideox.stanford.edu 2.62777123305
# www.linkedin.com 2.47724497321
# explorecourses.stanford.edu 2.29274118964
# gradescope.com 2.06008088603
# axess.sahr.stanford.edu 2.03705579848
# secure.bankofamerica.com 1.84702198656
# developers.google.com 1.8348630584
# ...

# %%
print_counter(get_hours_spent_on_domains_for_user('shivaal'))
# Out:
# docs.google.com 50.9505152577
# www.facebook.com 47.9491478893
# www.messenger.com 30.8438371754
# www.google.com 29.8193892806
# web.stanford.edu 22.1932980266
# mail.google.com 21.3583190571
# www.youtube.com 21.2033731272
# localhost:3000 15.54857595
# piazza.com 13.1625369489
# m.facebook.com 10.2351024687
#  9.20668123617
# stackoverflow.com 7.93413714125
# drive.google.com 6.18965462653
# i.imgur.com 5.92555030558
# canvas.stanford.edu 5.08415334317
# github.com 4.96418808038
# keep.google.com 3.74796362183
# www.reddit.com 3.74596126438
# imgur.com 3.68404104241
# www.amazon.com 3.53625874478
# localhost:8000 3.09521014459
# en.wikipedia.org 3.09078093391
# www.glassdoor.com 2.63060545932
# mvideox.stanford.edu 2.62777123305
# www.linkedin.com 2.47724497321
# explorecourses.stanford.edu 2.29274118964
# gradescope.com 2.06008088603
# axess.sahr.stanford.edu 2.03705579848
# secure.bankofamerica.com 1.84702198656
# developers.google.com 1.8348630584
# ...

# %%
print_counter(get_hours_spent_on_domains_for_user('jess'))
# Out:
# www.facebook.com 64.8427570951
# www.youtube.com 60.0986849869
# docs.google.com 49.392083225
# mail.google.com 27.6296611147
# www.google.com 13.8915152198
# localhost:8080 12.075208559
# web.stanford.edu 10.5990710029
# localhost:3000 8.31835358439
# calendar.google.com 4.20168928216
# www.instagram.com 3.99451615295
# stackoverflow.com 3.38277349514
# piazza.com 3.24605898865
# www.pandora.com 3.16860584574
# web.groupme.com 2.67040686652
#  2.56477674181
# www.airbnb.com 2.34762632067
# www.netflix.com 2.24326404765
# gradescope.com 1.87805051846
# www.express.com 1.84493108792
# en.wikipedia.org 1.78410832214
# github.com 1.75370082241
# www.linkedin.com 1.66473885295
# www.forever21.com 1.59974763536
# axess.sahr.stanford.edu 1.59870419135
# mvideox.stanford.edu 1.59650813605
# soundcloud.com 1.52461254489
# drive.google.com 1.28902663798
# www.lulus.com 1.27162042847
# www.yelp.com 1.26696246379
# www.hulu.com 1.2453527415
# www.amazon.com 1.23637129551
# ...

# %%
print get_reconstructed_focus_times_for_user('jess')[0]
# Out:
# {'end': 1454201702610.1948, 'url': 'http://www.pandora.com/', 'transition': 'typed', 'start': 1454201398426.873, 'active': 1454201402610.1948, 'end_transition': 'typed'}

# %%
print_counter(get_domain_to_num_history_visits_for_user('jess'))
# Out:
# www.facebook.com 16377
# docs.google.com 9812
# www.youtube.com 3560
# www.google.com 2402
# mail.google.com 2103
# localhost:8080 1818
# www.instagram.com 1300
# localhost:3000 1239
# web.stanford.edu 390
# photos.google.com 309
# calendar.google.com 286
# www.hulu.com 267
# www.airbnb.com 255
# www.linkedin.com 244
#  217
# piazza.com 217
# github.com 210
# personalityfactors.net 200
# www.express.com 184
# orgsync.com 175
# www.yelp.com 150
# drive.google.com 138
# stackoverflow.com 135
# scholar.google.com 134
# web.groupme.com 129
# www.lulus.com 127
# www.amazon.com 118
# www.ae.com 114
# www.pandora.com 111
# www.missguidedus.com 107
# www.netflix.com 106
# www.forever21.com 93
# gradescope.com 92
# www.picmonkey.com 87
# soundcloud.com 82
# canvas.stanford.edu 76
# weblogin.stanford.edu 75
# groupme.com 70
# axess.sahr.stanford.edu 69
# en.wikipedia.org 67
# mvideox.stanford.edu 66
# localhost:8000 51
# therighthairstyles.com 49
# www.w3schools.com 47
# ...

# %%
print_counter(get_domain_to_num_history_visits_for_user('shivaal'))
# Out:
# docs.google.com 19582
# www.google.com 5599
# www.facebook.com 5456
# www.messenger.com 2666
# web.stanford.edu 2176
# drive.google.com 1484
# www.youtube.com 1304
# localhost:3000 1233
# piazza.com 1038
# mail.google.com 880
# github.com 733
# i.imgur.com 694
#  689
# www.amazon.com 441
# canvas.stanford.edu 395
# developers.google.com 390
# imgur.com 388
# www.reddit.com 363
# stackoverflow.com 297
# m.facebook.com 272
# keep.google.com 252
# localhost:8000 186
# explorecourses.stanford.edu 162
# weblogin.stanford.edu 160
# app.asana.com 160
# gradescope.com 154
# www.bibme.org 147
# www.netflix.com 143
# en.wikipedia.org 143
# www.instagram.com 127
# www.glassdoor.com 126
# www.yikyak.com 120
# secure.bankofamerica.com 118
# www.linkedin.com 116
# materializecss.com 108
# calendar.google.com 106
# www.applyweb.com 101
# axess.sahr.stanford.edu 95
# console.developers.google.com 91
# www.rescuetime.com 90
# mvideox.stanford.edu 87
# 25live.collegenet.com 86
# quip.com 85
# ...

# %%
print_counter(get_domain_to_num_history_visits_for_user('geza'))
# Out:
# www.facebook.com 6581
# mail.google.com 3353
# docs.google.com 2353
# www.bing.com 2226
# www.google.com 1712
# en.wikipedia.org 1546
# mailchimp.com 1353
# github.com 1327
# calendar.google.com 1131
# www.messenger.com 1045
# www.youtube.com 959
# localhost:9876 698
# searchassist.verizon.com 634
# tmi.stanford.edu:5000 399
# www.duolingo.com 379
# stackoverflow.com 367
# en.wiktionary.org 359
# stanfordhcigfx.slack.com 358
# stanfordcsli.submittable.com 342
# slashdot.org 338
# translate.google.com 334
# finalfantasy.wikia.com 325
# photos.google.com 284
# scholar.google.com 270
# login.live.com 268
# h2o-release.s3.amazonaws.com 261
# localhost:8888 259
# chrome.google.com 253
# requester.mturk.com 246
# www.amazon.com 214
# localhost:8081 204
# www.airbnb.com 201
# scikit-learn.org 201
# zh.wikipedia.org 177
# www.quora.com 169
# localhost:3000 168
# docs.mongodb.org 157
# eprotocol.stanford.edu 148
# dashboard.heroku.com 141
# www.rescuetime.com 141
# www.nytimes.com 130
# ...
